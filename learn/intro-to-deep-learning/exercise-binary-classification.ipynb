# %% [markdown]
# **This notebook is an exercise in the [Intro to Deep Learning](https://www.kaggle.com/learn/intro-to-deep-learning) course.  You can reference the tutorial at [this link](https://www.kaggle.com/ryanholbrook/binary-classification).**
#
# ---

# %% [markdown]
# # Introduction #
#
# In this exercise, you'll build a model to predict hotel cancellations with a binary classifier.

# %%
# Setup plotting
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('animation', html='html5')

# Setup feedback system
from learntools.core import binder
binder.bind(globals())
from learntools.deep_learning_intro.ex6 import *

# %% [markdown]
# First, load the *Hotel Cancellations* dataset.

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer

hotel = pd.read_csv('../input/dl-course-data/hotel.csv')

X = hotel.copy()
y = X.pop('is_canceled')

X['arrival_date_month'] = \
    X['arrival_date_month'].map(
        {'January':1, 'February': 2, 'March':3,
         'April':4, 'May':5, 'June':6, 'July':7,
         'August':8, 'September':9, 'October':10,
         'November':11, 'December':12}
    )

features_num = [
    "lead_time", "arrival_date_week_number",
    "arrival_date_day_of_month", "stays_in_weekend_nights",
    "stays_in_week_nights", "adults", "children", "babies",
    "is_repeated_guest", "previous_cancellations",
    "previous_bookings_not_canceled", "required_car_parking_spaces",
    "total_of_special_requests", "adr",
]
features_cat = [
    "hotel", "arrival_date_month", "meal",
    "market_segment", "distribution_channel",
    "reserved_room_type", "deposit_type", "customer_type",
]

transformer_num = make_pipeline(
    SimpleImputer(strategy="constant"), # there are a few missing values
    StandardScaler(),
)
transformer_cat = make_pipeline(
    SimpleImputer(strategy="constant", fill_value="NA"),
    OneHotEncoder(handle_unknown='ignore'),
)

preprocessor = make_column_transformer(
    (transformer_num, features_num),
    (transformer_cat, features_cat),
)

# stratify - make sure classes are evenlly represented across splits
X_train, X_valid, y_train, y_valid = \
    train_test_split(X, y, stratify=y, train_size=0.75)

X_train = preprocessor.fit_transform(X_train)
X_valid = preprocessor.transform(X_valid)

input_shape = [X_train.shape[1]]

# %% [markdown]
# # 1) Define Model #
#
# The model we'll use this time will have both batch normalization and dropout layers. To ease reading we've broken the diagram into blocks, but you can define it layer by layer as usual.
#
# Define a model with an architecture given by this diagram:
#
# <figure style="padding: 1em;">
# <img src="https://i.imgur.com/V04o59Z.png" width="400" alt="Diagram of network architecture: BatchNorm, Dense, BatchNorm, Dropout, Dense, BatchNorm, Dropout, Dense.">
# <figcaption style="textalign: center; font-style: italic"><center>Diagram of a binary classifier.</center></figcaption>
# </figure>

# %%
from tensorflow import keras
from tensorflow.keras import layers

# YOUR CODE HERE: define the model given in the diagram
model = keras.Sequential([
    layers.BatchNormalization(input_shape=input_shape),
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(1, activation='sigmoid')
])

# Check your answer
q_1.check()
# Out:
# 2022-12-19 10:12:48.691987: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-19 10:12:48.785092: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-19 10:12:48.785989: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-19 10:12:48.787818: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-19 10:12:48.788155: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-19 10:12:48.788831: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-19 10:12:48.789552: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-19 10:12:51.108850: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-19 10:12:51.109809: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-19 10:12:51.110660: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-19 10:12:51.111377: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15401 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Correct

# %% [markdown]
# # 2) Add Optimizer, Loss, and Metric #
#
# Now compile the model with the Adam optimizer and binary versions of the cross-entropy loss and accuracy metric.

# %%
# YOUR CODE HERE
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['binary_accuracy']
)

# Check your answer
q_2.check()
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
#q_2.hint()
#q_2.solution()

# %% [markdown]
# Finally, run this cell to train the model and view the learning curves. It may run for around 60 to 70 epochs, which could take a minute or two.

# %%
early_stopping = keras.callbacks.EarlyStopping(
    patience=5,
    min_delta=0.001,
    restore_best_weights=True,
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=200,
    callbacks=[early_stopping],
)

history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot(title="Cross-entropy")
history_df.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot(title="Accuracy")
# Out:
# 2022-12-19 10:13:56.363508: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/200
# 175/175 [==============================] - 3s 6ms/step - loss: 0.4766 - binary_accuracy: 0.7758 - val_loss: 0.4369 - val_binary_accuracy: 0.8054
# Epoch 2/200
# 175/175 [==============================] - 1s 4ms/step - loss: 0.4237 - binary_accuracy: 0.8022 - val_loss: 0.4041 - val_binary_accuracy: 0.8143
# Epoch 3/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.4084 - binary_accuracy: 0.8093 - val_loss: 0.3942 - val_binary_accuracy: 0.8175
# Epoch 4/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.4003 - binary_accuracy: 0.8124 - val_loss: 0.3877 - val_binary_accuracy: 0.8207
# Epoch 5/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3965 - binary_accuracy: 0.8152 - val_loss: 0.3836 - val_binary_accuracy: 0.8225
# Epoch 6/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3922 - binary_accuracy: 0.8179 - val_loss: 0.3825 - val_binary_accuracy: 0.8247
# Epoch 7/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3875 - binary_accuracy: 0.8202 - val_loss: 0.3774 - val_binary_accuracy: 0.8256
# Epoch 8/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3841 - binary_accuracy: 0.8215 - val_loss: 0.3754 - val_binary_accuracy: 0.8290
# Epoch 9/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3804 - binary_accuracy: 0.8238 - val_loss: 0.3747 - val_binary_accuracy: 0.8291
# Epoch 10/200
# 175/175 [==============================] - 1s 4ms/step - loss: 0.3784 - binary_accuracy: 0.8242 - val_loss: 0.3710 - val_binary_accuracy: 0.8312
# Epoch 11/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3756 - binary_accuracy: 0.8270 - val_loss: 0.3689 - val_binary_accuracy: 0.8302
# Epoch 12/200
# 175/175 [==============================] - 1s 4ms/step - loss: 0.3733 - binary_accuracy: 0.8270 - val_loss: 0.3672 - val_binary_accuracy: 0.8315
# Epoch 13/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3700 - binary_accuracy: 0.8299 - val_loss: 0.3668 - val_binary_accuracy: 0.8304
# Epoch 14/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3689 - binary_accuracy: 0.8293 - val_loss: 0.3643 - val_binary_accuracy: 0.8338
# Epoch 15/200
# 175/175 [==============================] - 1s 4ms/step - loss: 0.3661 - binary_accuracy: 0.8310 - val_loss: 0.3660 - val_binary_accuracy: 0.8321
# Epoch 16/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3650 - binary_accuracy: 0.8309 - val_loss: 0.3652 - val_binary_accuracy: 0.8340
# Epoch 17/200
# 175/175 [==============================] - 1s 4ms/step - loss: 0.3632 - binary_accuracy: 0.8332 - val_loss: 0.3598 - val_binary_accuracy: 0.8348
# Epoch 18/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3617 - binary_accuracy: 0.8322 - val_loss: 0.3607 - val_binary_accuracy: 0.8362
# Epoch 19/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3594 - binary_accuracy: 0.8336 - val_loss: 0.3602 - val_binary_accuracy: 0.8356
# Epoch 20/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3575 - binary_accuracy: 0.8350 - val_loss: 0.3596 - val_binary_accuracy: 0.8356
# Epoch 21/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3570 - binary_accuracy: 0.8334 - val_loss: 0.3586 - val_binary_accuracy: 0.8362
# Epoch 22/200
# 175/175 [==============================] - 1s 4ms/step - loss: 0.3554 - binary_accuracy: 0.8354 - val_loss: 0.3598 - val_binary_accuracy: 0.8372
# Epoch 23/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3545 - binary_accuracy: 0.8360 - val_loss: 0.3616 - val_binary_accuracy: 0.8382
# Epoch 24/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3529 - binary_accuracy: 0.8368 - val_loss: 0.3592 - val_binary_accuracy: 0.8388
# Epoch 25/200
# 175/175 [==============================] - 1s 4ms/step - loss: 0.3511 - binary_accuracy: 0.8375 - val_loss: 0.3570 - val_binary_accuracy: 0.8374
# Epoch 26/200
# 175/175 [==============================] - 1s 4ms/step - loss: 0.3517 - binary_accuracy: 0.8370 - val_loss: 0.3586 - val_binary_accuracy: 0.8373
# Epoch 27/200
# 175/175 [==============================] - 1s 4ms/step - loss: 0.3503 - binary_accuracy: 0.8399 - val_loss: 0.3549 - val_binary_accuracy: 0.8387
# Epoch 28/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3485 - binary_accuracy: 0.8388 - val_loss: 0.3579 - val_binary_accuracy: 0.8386
# Epoch 29/200
# 175/175 [==============================] - 1s 4ms/step - loss: 0.3482 - binary_accuracy: 0.8391 - val_loss: 0.3548 - val_binary_accuracy: 0.8376
# Epoch 30/200
# 175/175 [==============================] - 1s 4ms/step - loss: 0.3458 - binary_accuracy: 0.8401 - val_loss: 0.3545 - val_binary_accuracy: 0.8403
# Epoch 31/200
# 175/175 [==============================] - 1s 4ms/step - loss: 0.3456 - binary_accuracy: 0.8400 - val_loss: 0.3537 - val_binary_accuracy: 0.8394
# Epoch 32/200
# 175/175 [==============================] - 1s 4ms/step - loss: 0.3447 - binary_accuracy: 0.8417 - val_loss: 0.3548 - val_binary_accuracy: 0.8388
# Epoch 33/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3437 - binary_accuracy: 0.8407 - val_loss: 0.3533 - val_binary_accuracy: 0.8409
# Epoch 34/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3423 - binary_accuracy: 0.8409 - val_loss: 0.3528 - val_binary_accuracy: 0.8408
# Epoch 35/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3431 - binary_accuracy: 0.8407 - val_loss: 0.3527 - val_binary_accuracy: 0.8415
# Epoch 36/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3410 - binary_accuracy: 0.8428 - val_loss: 0.3568 - val_binary_accuracy: 0.8392
# Epoch 37/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3404 - binary_accuracy: 0.8422 - val_loss: 0.3534 - val_binary_accuracy: 0.8405
# Epoch 38/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3398 - binary_accuracy: 0.8423 - val_loss: 0.3524 - val_binary_accuracy: 0.8398
# Epoch 39/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3383 - binary_accuracy: 0.8433 - val_loss: 0.3522 - val_binary_accuracy: 0.8425
# Epoch 40/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3379 - binary_accuracy: 0.8436 - val_loss: 0.3506 - val_binary_accuracy: 0.8418
# Epoch 41/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3386 - binary_accuracy: 0.8431 - val_loss: 0.3490 - val_binary_accuracy: 0.8422
# Epoch 42/200
# 175/175 [==============================] - 1s 4ms/step - loss: 0.3372 - binary_accuracy: 0.8432 - val_loss: 0.3523 - val_binary_accuracy: 0.8414
# Epoch 43/200
# 175/175 [==============================] - 1s 4ms/step - loss: 0.3364 - binary_accuracy: 0.8456 - val_loss: 0.3492 - val_binary_accuracy: 0.8428
# Epoch 44/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3351 - binary_accuracy: 0.8453 - val_loss: 0.3509 - val_binary_accuracy: 0.8423
# Epoch 45/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3357 - binary_accuracy: 0.8451 - val_loss: 0.3495 - val_binary_accuracy: 0.8430
# Epoch 46/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3351 - binary_accuracy: 0.8443 - val_loss: 0.3493 - val_binary_accuracy: 0.8421
# <AxesSubplot:title={'center':'Accuracy'}>

# %% [markdown]
# # 3) Train and Evaluate #
#
#
# What do you think about the learning curves? Does it look like the model underfit or overfit? Was the cross-entropy loss a good stand-in for accuracy?

# %%
# View the solution (Run this cell to receive credit!)
q_3.check()
# Out:
# Correct:
#
# Though we can see the training loss continuing to fall, the early stopping callback prevented any overfitting. Moreover, the accuracy rose at the same rate as the cross-entropy fell, so it appears that minimizing cross-entropy was a good stand-in. All in all, it looks like this training was a success!

# %% [markdown]
# # Conclusion #
#
# Congratulations! You've completed Kaggle's *Introduction to Deep Learning* course!
#
# With your new skills you're ready to take on more advanced applications like computer vision and sentiment classification. What would you like to do next?
#
# Why not try one of our *Getting Started* competitions?
#
# - Classify images with TPUs in [**Petals to the Metal**](https://www.kaggle.com/c/tpu-getting-started)
# - Create art with GANs in [**I'm Something of a Painter Myself**](https://www.kaggle.com/c/gan-getting-started)
# - Classify Tweets in [**Real or Not? NLP with Disaster Tweets**](https://www.kaggle.com/c/nlp-getting-started)
# - Detect contradiction and entailment in [**Contradictory, My Dear Watson**](https://www.kaggle.com/c/contradictory-my-dear-watson)
#
# Until next time, Kagglers!

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [course discussion forum](https://www.kaggle.com/learn/intro-to-deep-learning/discussion) to chat with other learners.*
